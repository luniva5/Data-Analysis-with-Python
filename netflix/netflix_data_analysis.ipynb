# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dataset = pd.read_csv('netflix_titles.csv')

# %%
dataset
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
dataset.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
dataset.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
dataset.shape
# Out:
# (8807, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ## cleaning data

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
dataset.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
dataset.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
dataset.rename(columns = {'type':'category','listed_in':'genre'}, inplace=True)

# %%
dataset
# Out:
#      show_id category                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
dataset.nunique()
# Out:
# show_id         8807
# category           2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# genre            514
# description     8775
# dtype: int64

# %%
dataset = dataset.set_index('show_id')

# %%
dataset.describe()
# Out:
#        release_year
# count   5332.000000
# mean    2012.742123
# std        9.625831
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
dataset.dtypes
# Out:
# category        object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# genre           object
# description     object
# dtype: object

# %%
dataset['release_year'].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %% [markdown]
# ## Bar Graph

# %%
dataset.head()
# Out:
#         category                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
dataset.groupby('category').category.count()
# Out:
# category
# Movie      6131
# TV Show    2676
# Name: category, dtype: int64

# %%
sns.countplot(data=dataset, x=dataset['category'])
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %% [markdown]
# ## Filtering

# %% [markdown]
# ### Movies released in 2020

# %%
dataset[(dataset['category'] == 'Movie') & (dataset['release_year'] == 2020)]
# Out:
#         category                                              title  \
# show_id
# s1         Movie                               Dick Johnson Is Dead
# s17        Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# s79        Movie                                     Tughlaq Durbar
# s85        Movie                               Omo Ghetto: the Saga
# s104       Movie                                     Shadow Parties
# ...          ...                                                ...
# s3047      Movie                      All the Freckles in the World
# s3061      Movie                                      Ghost Stories
# s5973      Movie                                   #cats_the_mewvie
# s7595      Movie                 Norm of the North: Family Vacation
# s8100      Movie                                        Straight Up
#
#                                                   director  \
# show_id
# s1                                         Kirsten Johnson
# ...

# %% [markdown]
# ### TV shows released in United States

# %%
dataset[(dataset['category'] == 'TV Show') & (dataset['country'] == 'United States')]
# Out:
#         category                                   title director  \
# show_id
# s16      TV Show                       Dear White People      NaN
# s41      TV Show  He-Man and the Masters of the Universe      NaN
# s56      TV Show                               Nailed It      NaN
# s68      TV Show                       Saved by the Bell      NaN
# s83      TV Show                                 Lucifer      NaN
# ...          ...                                     ...      ...
# s8711    TV Show                                   Weeds      NaN
# s8727    TV Show                    When Calls the Heart      NaN
# s8748    TV Show                               Winsanity      NaN
# s8756    TV Show                       Women Behind Bars      NaN
# s8781    TV Show                            Yo-Kai Watch      NaN
#
#                                                       cast        country  \
# show_id
# s16      Logan Browning, Brandon P. Bell, DeRon Horton,...  United States
# ...

# %% [markdown]
# ### top 10 directors

# %%
dataset['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# ## Show all the records where "category is movie and genre is comedy" or "country is United Kingdom"

# %%
dataset[(dataset["category"] == "Movie") & (dataset["genre"] == "Comedies") | (dataset["country"] == "United Kingdom")]
# Out:
#         category                                   title         director  \
# show_id
# s9       TV Show           The Great British Baking Show  Andy Devonshire
# s28        Movie                               Grown Ups     Dennis Dugan
# s33      TV Show                           Sex Education              NaN
# s66      TV Show                            Numberblocks              NaN
# s73      TV Show  Jack Whitehall: Travels with My Father              NaN
# ...          ...                                     ...              ...
# s8741    TV Show                             Wild Alaska              NaN
# s8742    TV Show                             Wild Arabia              NaN
# s8745      Movie                                Williams  Morgan Matthews
# s8759    TV Show                  World's Busiest Cities              NaN
# s8787      Movie                            You Can Tutu      James Brown
#
# ...

# %%
dataset.sort_values(by = 'release_year', ascending = False)
# Out:
#         category                                          title  \
# show_id
# s694       Movie                         Ali & Ratu Ratu Queens
# s782       Movie          Black Holes | The Edge of All We Know
# s763       Movie                                   Sweet & Sour
# s764     TV Show                                    Sweet Tooth
# s765       Movie                   Trippin' with the Kandasamys
# ...          ...                                            ...
# s8661      Movie  Undercover: How to Operate Behind Enemy Lines
# s8764      Movie                WWII: Report from the Aleutians
# s8206      Movie                           The Battle of Midway
# s7791      Movie                                 Prelude to War
# s4251    TV Show              Pioneers: First Women Filmmakers*
#
#                director                                               cast  \
# show_id
# s694     Lucky Kuswandi  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...
# ...
